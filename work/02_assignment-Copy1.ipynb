# %% [markdown]
# # Assignment: Working with Data

# %% [markdown]
# >Using the data below, answer the following questions:
#
# >1) Which entities (top 5) had the largest population density in 2020?
# >2) Which entities have more water area than land area?
# >3) Which entities increased in population the most in the last 10 years?
# >4) What state bird accounts for the largest population as of 2020? Land area?
# >5) How many entities' largest city is their capital city?
# >6) Which city has the largest percent drop from their largest city to their 5th largest? 100*(1st largest - 5th largest)/(1st largest)

# %%
import pandas as pd

# %%
facts = pd.read_csv('../data/state_facts.tsv',delimiter="\t")
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...        City_1 city_1_pop       City_2  \
# ...

# %%
#1:
facts['populationdensity20']=facts['Pop_2020']/facts['Area_land']

# %%
facts
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 0                         Alabama     135767     131171        4597
# 1                          Alaska    1723337    1477953      245384
# 2                  American Samoa       1505        198        1307
# 3                         Arizona     295234     294207        1026
# 4                        Arkansas     137732     134771        2961
# 5                      California     423967     403466       20501
# 6                        Colorado     269601     268431        1170
# 7                     Connecticut      14357      12542        1816
# 8                        Delaware       6446       5047        1399
# 9            District of Columbia        177        158          19
# 10                        Florida     170312     138887       31424
# 11                        Georgia     153910     148959        4951
# 12                           Guam       1478        543         935
# ...

# %%
facts.sort_values(by='populationdensity20',ascending=False).head(5)
# Out:
#                      State  Area_tot  Area_land  Area_water   Pop_2020  \
# 9    District of Columbia        177        158          19   689545.0
# 32             New Jersey      22591      19047        3544  9288994.0
# 43           Rhode Island       4001       2678        1324  1097379.0
# 42            Puerto Rico      13791       8868        4924  3285874.0
# 23          Massachusetts      27336      20202        7134  7029917.0
#
#     Pop_2010 Rep_seats                               State_bird  \
# 9     601723       1*                              Wood thrush
# 32   8791894        12  Eastern goldfinch (American goldfinch)
# 43   1052567         2                        Rhode Island Red
# 42   3725789       1*                                     None
# 23   6547629         9                  Black-capped chickadee
#
#              State_flower                                 State_motto  ...  \
# 9   American Beauty Rose                            Justitia Omnibus   ...
# ...

# %%
#Answer 1)District of Columbia

# %%
#2:
facts['waterlandratio']=facts['Area_water']/facts['Area_land']
facts.sort_values(by='waterlandratio', ascending=False)
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 37       Northern Mariana Islands       5117        472        4644
# 2                  American Samoa       1505        198        1307
# 48   United States Virgin Islands       1898        348        1550
# 12                           Guam       1478        543         935
# 24                       Michigan     250487     146435      104052
# 13                         Hawaii      28313      16635       11678
# 42                    Puerto Rico      13791       8868        4924
# 43                   Rhode Island       4001       2678        1324
# 23                  Massachusetts      27336      20202        7134
# 22                       Maryland      32131      25142        6990
# 8                        Delaware       6446       5047        1399
# 10                        Florida     170312     138887       31424
# 20                      Louisiana     135659     111898       23761
# ...

# %%
#Answer 2)Northern Mariana Islands

# %%
facts['increase10']=facts['Pop_2020']-facts['Pop_2010']
facts.sort_values(by='increase10', ascending=False)
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 47                          Texas     695662     676587       19075
# 10                        Florida     170312     138887       31424
# 5                      California     423967     403466       20501
# 11                        Georgia     153910     148959        4951
# 52                     Washington     184661     172119       12542
# 35                 North Carolina     139391     125920       13471
# 34                       New York     141297     122057       19240
# 3                         Arizona     295234     294207        1026
# 6                        Colorado     269601     268431        1170
# 51                       Virginia     110787     102279        8508
# 46                      Tennessee     109153     106798        2355
# 49                           Utah     219882     212818        7064
# 32                     New Jersey      22591      19047        3544
# ...

# %%
#Answer 3) Texas

# %%
facts.sort_values(by='Pop_2020', ascending=False)
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 5                      California     423967     403466       20501
# 47                          Texas     695662     676587       19075
# 10                        Florida     170312     138887       31424
# 34                       New York     141297     122057       19240
# 41                   Pennsylvania     119280     115883        3397
# 15                       Illinois     149995     143793        6202
# 38                           Ohio     116098     105829       10269
# 11                        Georgia     153910     148959        4951
# 35                 North Carolina     139391     125920       13471
# 24                       Michigan     250487     146435      104052
# 32                     New Jersey      22591      19047        3544
# 51                       Virginia     110787     102279        8508
# 52                     Washington     184661     172119       12542
# ...

# %%
#Answer 4) California quail

# %%
facts.columns
# Out:
# Index(['State', 'Area_tot', 'Area_land', 'Area_water', 'Pop_2020', 'Pop_2010',
#        'Rep_seats', 'State_bird', 'State_flower', 'State_motto', 'Motto_trans',
#        'USPS_code', 'GDP_2020', 'GDP_2019', 'Capital', 'Capital_pop', 'City_1',
#        'city_1_pop', 'City_2', 'city_2_pop', 'City_3', 'city_3_pop', 'City_4',
#        'city_4_pop', 'City_5', 'city_5_pop', 'populationdensity20',
#        'waterlandratio', 'increase10'],
#       dtype='object')

# %%
citypopdf=facts[['State', 'Capital','City_1','city_1_pop','City_2','city_2_pop','City_3','city_3_pop','City_4','city_4_pop','City_5','city_5_pop']]

# %%
citypopdf
# Out:
#                              State            Capital             City_1  \
# 0                         Alabama         Montgomery         Birmingham
# 1                          Alaska             Juneau          Anchorage
# 2                  American Samoa           Pago Pago            Tafuna
# 3                         Arizona            Phoenix            Phoenix
# 4                        Arkansas        Little Rock        Little Rock
# 5                      California         Sacramento        Los Angeles
# 6                        Colorado             Denver             Denver
# 7                     Connecticut           Hartford         Bridgeport
# 8                        Delaware              Dover         Wilmington
# 9            District of Columbia   Washington, D.C.   Washington, D.C.
# 10                        Florida        Tallahassee       Jacksonville
# 11                        Georgia            Atlanta            Atlanta
# ...

# %%
citypopdf.sort_values(by=['city_1_pop','city_2_pop','city_3_pop','city_4_pop','city_5_pop'], ascending=False)
# Out:
#                              State            Capital             City_1  \
# 34                       New York             Albany      New York City
# 5                      California         Sacramento        Los Angeles
# 15                       Illinois        Springfield            Chicago
# 47                          Texas             Austin            Houston
# 3                         Arizona            Phoenix            Phoenix
# 41                   Pennsylvania         Harrisburg       Philadelphia
# 10                        Florida        Tallahassee       Jacksonville
# 38                           Ohio           Columbus           Columbus
# 35                 North Carolina            Raleigh          Charlotte
# 16                        Indiana       Indianapolis       Indianapolis
# 52                     Washington            Olympia            Seattle
# 6                        Colorado             Denver             Denver
# ...

# %%
equalcappop=citypopdf[(citypopdf['Capital'])==(citypopdf['City_1'])]
equalcappop
# Out:
#                      State            Capital             City_1  city_1_pop  \
# 3                 Arizona            Phoenix            Phoenix      1680992
# 4                Arkansas        Little Rock        Little Rock       197312
# 6                Colorado             Denver             Denver       727211
# 9    District of Columbia   Washington, D.C.   Washington, D.C.       702455
# 11                Georgia            Atlanta            Atlanta       506811
# 14                  Idaho              Boise              Boise       228959
# 16                Indiana       Indianapolis       Indianapolis       876384
# 17                   Iowa         Des Moines         Des Moines       214237
# 23          Massachusetts             Boston             Boston       692600
# 26            Mississippi            Jackson            Jackson       160628
# 38                   Ohio           Columbus           Columbus       898553
# ...

# %%
rowcount=len(equalcappop)
print (rowcount)
# Out:
# 17

# %%
#Answer 5) 17 entities/states

# %%
citypopdf['percentdrop']=100*(citypopdf['city_1_pop']-citypopdf['city_5_pop'])/(citypopdf['city_1_pop'])
# Out:
# /tmp/ipykernel_1526821/3702677261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   citypopdf['percentdrop']=100*(citypopdf['city_1_pop']-citypopdf['city_5_pop'])/(citypopdf['city_1_pop'])

# %%
citypopdf
# Out:
#                              State            Capital             City_1  \
# 0                         Alabama         Montgomery         Birmingham
# 1                          Alaska             Juneau          Anchorage
# 2                  American Samoa           Pago Pago            Tafuna
# 3                         Arizona            Phoenix            Phoenix
# 4                        Arkansas        Little Rock        Little Rock
# 5                      California         Sacramento        Los Angeles
# 6                        Colorado             Denver             Denver
# 7                     Connecticut           Hartford         Bridgeport
# 8                        Delaware              Dover         Wilmington
# 9            District of Columbia   Washington, D.C.   Washington, D.C.
# 10                        Florida        Tallahassee       Jacksonville
# 11                        Georgia            Atlanta            Atlanta
# ...

# %%
citypopdf.sort_values(by='percentdrop',ascending=False)
# Out:
#                              State            Capital             City_1  \
# 34                       New York             Albany      New York City
# 1                          Alaska             Juneau          Anchorage
# 15                       Illinois        Springfield            Chicago
# 41                   Pennsylvania         Harrisburg       Philadelphia
# 19                       Kentucky          Frankfort         Louisville
# 29                       Nebraska            Lincoln              Omaha
# 33                     New Mexico           Santa Fe        Albuquerque
# 13                         Hawaii           Honolulu          Honolulu1
# 16                        Indiana       Indianapolis       Indianapolis
# 45                   South Dakota             Pierre        Sioux Falls
# 54                      Wisconsin            Madison          Milwaukee
# 5                      California         Sacramento        Los Angeles
# ...

# %%
#Answer 6) New York

# %% [markdown]
# >Using the "state_dates.tsv" data, answer the remaining questions. You will need to merge the two data sets together:
#
# >7) Of the states that joined the United States before 1790, what is the most common state flower?
# >8) Which has the larger population density, the most dense US Territory or the least dense state?
# >9) Make a graph that plots the populations of the largest city in each entity in the order in which they joined the US. Make the bars black
# >10) Make two additional graphs like the one above but one for land area (green bars) and one for water area (blue bars)

# %% [markdown]
# Hint: `pd.read_csv('../data/state_dates.tsv',delimiter="\t")`
#
# Hint: You likely want to convert the Date column to datetime. You might have to correct errors in the data as well.
#
# Hint: `states['Date']<pd.datetime(1790,1,1)`
#
# Hint: `pd.merge(****,****,left_on='USPS_code',right_on='Abbreviation',how='outer')`

# %%
# Sample code to help with the plots

#import matplotlib as plt
#%config InlineBackend.figure_format ='retina' #This makes your plot clearer


#plot = *your df by date*[[*column*,'Abbreviation']].plot(kind='bar',figsize=(10,4))
#plot.set_xticklabels(*your df by date*['Abbreviation']);

# %%
import pandas as pd

# %%
datesdf=pd.read_csv('../data/state_dates.tsv',delimiter="\t")
datesdf
# Out:
#                             Name               Date            Status  \
# 0                       Alabama   December 14, 1819             State
# 1                        Alaska     January 3, 1959             State
# 2                 American Samoa     April 17, 1900         Territory
# 3                       Arizona   February 14, 1912             State
# 4                      Arkansas       June 15, 1836             State
# 5                    California   September 9, 1850             State
# 6                      Colorado      August 1, 1876             State
# 7                   Connecticut     January 9, 1788             State
# 8                      Delaware    December 7, 1787             State
# 9           District of Columbia  February 21, 1871  Federal District
# 10                      Florida       March 3, 1845             State
# 11                      Georgia     January 2, 1788             State
# ...

# %%
datesdf['Date_Fixed']=pd.to_datetime(datesdf['Date'],errors='raise')
datesdf[['Name', 'Date', 'Date_Fixed', 'Status']]
# Out:
#                             Name               Date Date_Fixed  \
# 0                       Alabama   December 14, 1819 1819-12-14
# 1                        Alaska     January 3, 1959 1959-01-03
# 2                 American Samoa     April 17, 1900 1900-04-17
# 3                       Arizona   February 14, 1912 1912-02-14
# 4                      Arkansas       June 15, 1836 1836-06-15
# 5                    California   September 9, 1850 1850-09-09
# 6                      Colorado      August 1, 1876 1876-08-01
# 7                   Connecticut     January 9, 1788 1788-01-09
# 8                      Delaware    December 7, 1787 1787-12-07
# 9           District of Columbia  February 21, 1871 1871-02-21
# 10                      Florida       March 3, 1845 1845-03-03
# 11                      Georgia     January 2, 1788 1788-01-02
# 12                          Guam     April 11, 1899 1899-04-11
# 13                       Hawaii     August 21, 1959 1959-08-21
# ...

# %%
datesdf
# Out:
#                             Name               Date            Status  \
# 0                       Alabama   December 14, 1819             State
# 1                        Alaska     January 3, 1959             State
# 2                 American Samoa     April 17, 1900         Territory
# 3                       Arizona   February 14, 1912             State
# 4                      Arkansas       June 15, 1836             State
# 5                    California   September 9, 1850             State
# 6                      Colorado      August 1, 1876             State
# 7                   Connecticut     January 9, 1788             State
# 8                      Delaware    December 7, 1787             State
# 9           District of Columbia  February 21, 1871  Federal District
# 10                      Florida       March 3, 1845             State
# 11                      Georgia     January 2, 1788             State
# ...

# %%
#facts ['State']= datesdf['Name']
mergeddata = pd.merge(facts,datesdf, left_on="USPS_code", right_on="Abbreviation", how = 'outer')
mergeddata
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 0                         Alabama     135767     131171        4597
# 1                          Alaska    1723337    1477953      245384
# 2                  American Samoa       1505        198        1307
# 3                         Arizona     295234     294207        1026
# 4                        Arkansas     137732     134771        2961
# 5                      California     423967     403466       20501
# 6                        Colorado     269601     268431        1170
# 7                     Connecticut      14357      12542        1816
# 8                        Delaware       6446       5047        1399
# 9            District of Columbia        177        158          19
# 10                        Florida     170312     138887       31424
# 11                        Georgia     153910     148959        4951
# 12                           Guam       1478        543         935
# ...

# %%
thirteencolonies=mergeddata[mergeddata['Date_Fixed']<pd.datetime(1790,1,1)]
# Out:
# /tmp/ipykernel_1526821/3746879015.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   thirteencolonies=mergeddata[mergeddata['Date_Fixed']<pd.datetime(1790,1,1)]

# %%
thirteencolonies['State_flower'].value_counts()
# Out:
# Mountain laurel      2
# Peach blossom        1
# Cherokee rose        1
# Black-eyed susan     1
# Mayflower            1
# Purple lilac         1
# Violet               1
# Rose                 1
# Flowering dogwood    1
# Yellow jessamine     1
# American dogwood     1
# Name: State_flower, dtype: int64

# %%
#Answer 7) Mountain laurel

# %%
mergeddata.sort_values(by='populationdensity20',ascending=False)
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 9            District of Columbia        177        158          19
# 32                     New Jersey      22591      19047        3544
# 43                   Rhode Island       4001       2678        1324
# 42                    Puerto Rico      13791       8868        4924
# 23                  Massachusetts      27336      20202        7134
# 48   United States Virgin Islands       1898        348        1550
# 7                     Connecticut      14357      12542        1816
# 2                  American Samoa       1505        198        1307
# 22                       Maryland      32131      25142        6990
# 8                        Delaware       6446       5047        1399
# 34                       New York     141297     122057       19240
# 10                        Florida     170312     138887       31424
# 41                   Pennsylvania     119280     115883        3397
# ...

# %%
statemergeddata=mergeddata[mergeddata['Status']=='State']
statemergeddata
# Out:
#                State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 0           Alabama     135767     131171        4597   5024279.0   4779736
# 1            Alaska    1723337    1477953      245384    733391.0    710231
# 3           Arizona     295234     294207        1026   7151502.0   6392017
# 4          Arkansas     137732     134771        2961   3011524.0   2915918
# 5        California     423967     403466       20501  39538223.0  37253956
# 6          Colorado     269601     268431        1170   5773714.0   5029196
# 7       Connecticut      14357      12542        1816   3605944.0   3574097
# 8          Delaware       6446       5047        1399    989948.0    897934
# 10          Florida     170312     138887       31424  21538187.0  18801310
# 11          Georgia     153910     148959        4951  10711908.0   9687653
# 13           Hawaii      28313      16635       11678   1455271.0   1360301
# ...

# %%
statemergeddata.sort_values(by='populationdensity20',ascending=True)
# Out:
#                State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 1            Alaska    1723337    1477953      245384    733391.0    710231
# 55          Wyoming     253335     251470        1864    576851.0    563626
# 28          Montana     380831     376962        3869   1084225.0    989415
# 36     North Dakota     183108     178711        4397    779094.0    672591
# 45     South Dakota     199729     196350        3379    886667.0    814180
# 33       New Mexico     314917     314161         757   2117522.0   2059179
# 14            Idaho     216443     214045        2398   1839106.0   1567582
# 29         Nebraska     200330     198974        1356   1961504.0   1826341
# 30           Nevada     286380     284332        2048   3104614.0   2700551
# 18           Kansas     213100     211754        1346   2937880.0   2853118
# 49             Utah     219882     212818        7064   3271616.0   2763885
# ...

# %%
territorymergeddata=mergeddata[mergeddata['Status']=='Territory']
territorymergeddata
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 2                  American Samoa       1505        198        1307
# 12                           Guam       1478        543         935
# 37       Northern Mariana Islands       5117        472        4644
# 42                    Puerto Rico      13791       8868        4924
# 48   United States Virgin Islands       1898        348        1550
#
#      Pop_2020  Pop_2010 Rep_seats           State_bird  \
# 2     49437.0     55519       1*                  None
# 12      168.4    159358       1*   Guam rail (ko'ko')
# 37       51.0     53883       1*   Mariana fruit-dove
# 42  3285874.0   3725789       1*                 None
# 48   106235.0    106405       1*      California gull
#
#                   State_flower                  State_motto  ...  \
# 2             Paogo (Ulafala)        Samoa, Muamua Le Atua   ...
# 12  Bougainvillea spectabilis   Where America's Day Begins   ...
# ...

# %%
territorymergeddata.sort_values(by='populationdensity20',ascending=False)
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 42                    Puerto Rico      13791       8868        4924
# 48   United States Virgin Islands       1898        348        1550
# 2                  American Samoa       1505        198        1307
# 12                           Guam       1478        543         935
# 37       Northern Mariana Islands       5117        472        4644
#
#      Pop_2020  Pop_2010 Rep_seats           State_bird  \
# 42  3285874.0   3725789       1*                 None
# 48   106235.0    106405       1*      California gull
# 2     49437.0     55519       1*                  None
# 12      168.4    159358       1*   Guam rail (ko'ko')
# 37       51.0     53883       1*   Mariana fruit-dove
#
#                   State_flower                  State_motto  ...  \
# 42               Flor de Maga       Joannes Est Nomen Eius   ...
# 48               Yellow Elder      United in Pride and Hope  ...
# ...

# %%
#Answer 8) Puerto Rico

# %%
import matplotlib as plt
# %config InlineBackend.figure_format ='retina'

# %%
alldf=mergeddata[['State', 'City_1', 'city_1_pop','Date_Fixed']].sort_values(by='Date_Fixed',ascending=True)
alldf
# Out:
#                              State             City_1  city_1_pop Date_Fixed
# 8                        Delaware         Wilmington        70635 1787-12-07
# 41                   Pennsylvania       Philadelphia      1587828 1787-12-12
# 32                     New Jersey             Newark       282090 1787-12-18
# 11                        Georgia            Atlanta       506811 1788-01-02
# 7                     Connecticut         Bridgeport       144900 1788-01-09
# 23                  Massachusetts             Boston       692600 1788-02-06
# 22                       Maryland          Baltimore       594282 1788-04-28
# 44                 South Carolina         Charleston       136208 1788-05-23
# 31                  New Hampshire         Manchester       112525 1788-06-21
# 51                       Virginia     Virginia Beach       450189 1788-06-25
# 34                       New York      New York City      8879928 1788-07-26
# ...

# %%
ascendingpop=alldf.sort_values(by='city_1_pop',ascending=True)
ascendingpop
# Out:
#                              State             City_1  city_1_pop Date_Fixed
# 2                  American Samoa             Tafuna         7945 1900-04-17
# 48   United States Virgin Islands   Charlotte Amalie        18481 1917-03-31
# 50                        Vermont         Burlington        42899 1791-03-04
# 12                           Guam             Dededo        44943 1899-04-11
# 53                  West Virginia         Charleston        46536 1863-06-20
# 37       Northern Mariana Islands            Saipan2        48220 1986-11-04
# 55                        Wyoming           Cheyenne        64235 1890-07-10
# 21                          Maine           Portland        66417 1820-03-15
# 8                        Delaware         Wilmington        70635 1787-12-07
# 31                  New Hampshire         Manchester       112525 1788-06-21
# 28                        Montana           Billings       116827 1889-11-08
# ...

# %%
popjoineddf=mergeddata[['city_1_pop','Date_Fixed']].sort_values(by='Date_Fixed',ascending=True)
popjoineddf
# Out:
#     city_1_pop Date_Fixed
# 8        70635 1787-12-07
# 41     1587828 1787-12-12
# 32      282090 1787-12-18
# 11      506811 1788-01-02
# 7       144900 1788-01-09
# 23      692600 1788-02-06
# 22      594282 1788-04-28
# 44      136208 1788-05-23
# 31      112525 1788-06-21
# 51      450189 1788-06-25
# 34     8879928 1788-07-26
# 35      882367 1789-11-21
# 43      179883 1790-05-29
# 50       42899 1791-03-04
# 19      620578 1792-06-01
# 46      670820 1796-06-01
# 38      898553 1803-03-01
# 20      399187 1812-04-30
# 16      876384 1816-12-11
# 26      160628 1817-12-10
# 15     2705994 1818-12-03
# 0       208928 1819-12-14
# 21       66417 1820-03-15
# 27      507928 1821-08-10
# 4       197312 1836-06-15
# 24      672662 1837-01-26
# 10      907953 1845-03-03
# 47     2325502 1845-12-29
# 17      214237 1846-12-28
# 54      592025 1848-05-29
# 5      3997984 1850-09-09
# 25      427728 1858-05-11
# 40      661189 1859-02-14
# 18      389225 1861-01-29
# ...

# %%
popjoineddf['Date_Fixed_Formatted']=popjoineddf['Date_Fixed'].dt.strftime('%Y')
popjoineddf
# Out:
#     city_1_pop Date_Fixed Date_Fixed_Formatted
# 8        70635 1787-12-07                 1787
# 41     1587828 1787-12-12                 1787
# 32      282090 1787-12-18                 1787
# 11      506811 1788-01-02                 1788
# 7       144900 1788-01-09                 1788
# 23      692600 1788-02-06                 1788
# 22      594282 1788-04-28                 1788
# 44      136208 1788-05-23                 1788
# 31      112525 1788-06-21                 1788
# 51      450189 1788-06-25                 1788
# 34     8879928 1788-07-26                 1788
# 35      882367 1789-11-21                 1789
# 43      179883 1790-05-29                 1790
# 50       42899 1791-03-04                 1791
# 19      620578 1792-06-01                 1792
# 46      670820 1796-06-01                 1796
# 38      898553 1803-03-01                 1803
# 20      399187 1812-04-30                 1812
# 16      876384 1816-12-11                 1816
# ...

# %%
dpdf=popjoineddf[['city_1_pop','Date_Fixed_Formatted']].sort_values(by='Date_Fixed_Formatted',ascending=True)
dpdf
# Out:
#     city_1_pop Date_Fixed_Formatted
# 8        70635                 1787
# 41     1587828                 1787
# 32      282090                 1787
# 11      506811                 1788
# 7       144900                 1788
# 23      692600                 1788
# 22      594282                 1788
# 44      136208                 1788
# 31      112525                 1788
# 51      450189                 1788
# 34     8879928                 1788
# 35      882367                 1789
# 43      179883                 1790
# 50       42899                 1791
# 19      620578                 1792
# 46      670820                 1796
# 38      898553                 1803
# 20      399187                 1812
# 16      876384                 1816
# 26      160628                 1817
# 15     2705994                 1818
# 0       208928                 1819
# 21       66417                 1820
# 27      507928                 1821
# 4       197312                 1836
# ...

# %%
#Answer 9) BELOW
plot = dpdf.plot(kind='bar', color='black', figsize=(20,10))
plot.set_xticklabels(alldf ['Date_Fixed'].dt.strftime('%Y,%m,%d')+','+alldf['State']+','+alldf['City_1']);
plot.set_yticklabels(alldf['city_1_pop'])
plot
# Out:
# /tmp/ipykernel_1526821/2444364230.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot.set_yticklabels(alldf['city_1_pop'])
# <AxesSubplot:>

# %%
#Answer 10) BELOW
mergeddata.sort_values(by='Date_Fixed',ascending=True).plot(x='Name', y='Area_land',kind='bar',color='green', figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
#Answer 10) BELOW
mergeddata.sort_values(by='Date_Fixed',ascending=True).plot(x='Name', y='Area_water',kind='bar',color='blue', figsize=(15, 6))
# Out:
# <AxesSubplot:xlabel='Name'>
